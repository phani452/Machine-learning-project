# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Phaneendra\\Desktop\\ML 2019'

# %%
os.chdir('C:\\Users\\Phaneendra\\downloads')

# %% [markdown]
# # reading data

# %%
data=pd.read_csv(r'C:\Users\Phaneendra\Downloads\wk3_kc_house_train_data.csv\wk3_kc_house_train_data.csv')        #reading data

# %%
data.head()
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  2487200875  20141209T000000   604000.0         4       3.00         1960
# 1  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 2  9212900260  20140527T000000   468000.0         2       1.00         1160
# 3   114101516  20140528T000000   310000.0         3       1.00         1430
# 4  6054650070  20141007T000000   400000.0         3       1.75         1370
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5000     1.0           0     0  ...      7        1050            910
# 1    101930     1.0           0     0  ...     11        3890           1530
# 2      6000     1.0           0     0  ...      7         860            300
# 3     19901     1.5           0     0  ...      7        1430              0
# 4      9680     1.0           0     0  ...      7        1370              0
#
# ...

# %%
data.shape
# Out:
# (9761, 21)

# %%
data.columns            #columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.dtypes             #datatype of data in each column
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
data.isnull().sum()         #checking for null values
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ###### from above we can say there are no null values in data

# %%
data.describe()
# Out:
#                  id         price     bedrooms    bathrooms   sqft_living  \
# count  9.761000e+03  9.761000e+03  9761.000000  9761.000000   9761.000000
# mean   4.605288e+09  5.427350e+05     3.375884     2.117175   2086.734146
# std    2.876044e+09  3.795276e+05     0.960697     0.773971    927.194303
# min    1.200019e+06  8.000000e+04     0.000000     0.000000    290.000000
# 25%    2.126049e+09  3.200000e+05     3.000000     1.750000   1420.000000
# 50%    3.905041e+09  4.500000e+05     3.000000     2.250000   1910.000000
# 75%    7.338403e+09  6.490000e+05     4.000000     2.500000   2570.000000
# max    9.900000e+09  7.700000e+06    33.000000     8.000000  12050.000000
#
#            sqft_lot       floors   waterfront         view    condition  \
# count  9.761000e+03  9761.000000  9761.000000  9761.000000  9761.000000
# mean   1.521526e+04     1.486067     0.008401     0.248028     3.415531
# std    4.126673e+04     0.532317     0.091275     0.787877     0.650552
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\Phaneendra\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# # Univariate Analysis

# %%
data.hist(figsize=(12,12),grid=False)           #plooting histogrms for each column
plt.show()

# %% [markdown]
# ###### From above graphs we can infer that
# ###### grade is normally distributed
# ###### sqft_above ,sqft_basement,sqt_living15 are right skewed

# %% [markdown]
# # coreelation matrix

# %%
corr_matrix = data.corr()
corr_matrix
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.005972 -0.002571   0.005821    -0.007559 -0.130303
# price         -0.005972  1.000000  0.300808   0.527532     0.705052  0.094143
# bedrooms      -0.002571  0.300808  1.000000   0.506070     0.560989  0.028895
# bathrooms      0.005821  0.527532  0.506070   1.000000     0.758930  0.079435
# sqft_living   -0.007559  0.705052  0.560989   0.758930     1.000000  0.162786
# sqft_lot      -0.130303  0.094143  0.028895   0.079435     0.162786  1.000000
# floors         0.007793  0.262954  0.181042   0.501899     0.366219 -0.003543
# waterfront     0.000834  0.274977 -0.006803   0.061483     0.097203  0.029420
# view           0.023355  0.399658  0.079863   0.182988     0.285735  0.099221
# condition     -0.015321  0.044732  0.036135  -0.115382    -0.047938 -0.008722
# grade          0.012491  0.665567  0.342305   0.660925     0.764819  0.115611
# ...

# %%
import seaborn as sns #graphic tool

# %% [markdown]
# # heatmap

# %%
mask = np.zeros_like(corr_matrix)                                              #heatmap with correlation values

f, ax = plt.subplots(figsize=(16,16))
ax = sns.heatmap(corr_matrix, mask=mask, vmax=.3, square=True,annot=True)

# %% [markdown]
# ###### from above heatmap we can infer that
# ###### the highly correlated columns are
# ###### 'bedrooms','bathrooms','sqft_living','view','grade','sqft_above','sqft_basement','sqft_living15

# %%
'''from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha=0.5, figsize=(14, 14), 
               diagonal='hist')
plt.show()'''
# Out:
# "from pandas.plotting import scatter_matrix\nscatter_matrix(data, alpha=0.5, figsize=(14, 14), \n               diagonal='hist')\nplt.show()"

# %% [markdown]
# # scatter plot of highly corelated variables

# %%
plt.scatter(x=data.sqft_living,y=data.price,color='red') #scatter plot between sqft_living and price
plt.xlabel('sqft_living')
plt.ylabel('price')
plt.show()

# %% [markdown]
# #### From above graph we can infer that the sqft_living and price have linear relationship.

# %% [markdown]
# # Applying log transformation

# %%
plt.scatter(x=np.log(data.sqft_living),y=np.log(data.price),color='red') #using logirthamic function
plt.xlabel('sqft_living')
plt.ylabel('price')
plt.show()

# %% [markdown]
# ### But after applying log transformation we can see a strong linear relationship between sqft_living and price.

# %%
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(15,10))
sns.distplot(data['sqft_living'],hist=True,kde=True,rug=False,label='sqft_living',norm_hist=True)

# %% [markdown]
# ###### From above graphs we can infer that the distribuition is right skewed and there are outliers

# %%
plt.scatter(x=data.sqft_above,y=data.price,color='red') #scatter plot between sqft_living and price
plt.xlabel('sqft_above')
plt.ylabel('price')
plt.show()

# %% [markdown]
# ### From above graph we can infer that the sqft_living and price have linear relationship

# %% [markdown]
# # applying log transformation

# %%
plt.scatter(x=np.log(data.sqft_above),y=np.log(data.price),color='red') #using logirthamic function
plt.xlabel('sqft_above')
plt.ylabel('price')
plt.show()

# %% [markdown]
# #### But after applying log transformation we can see a strong linear relationship between sqft_living and price.

# %%
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(15,10))
sns.distplot(data['sqft_lot'],hist=True,kde=True,rug=False,label='sqft_lot',norm_hist=True)

# %% [markdown]
# #### From above graphs we can infer that the distribuition is highly right skewed and there are outliers

# %%
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(15,10))
sns.distplot(data['sqft_above'],hist=True,kde=True,rug=False,label='sqft_above',norm_hist=True)

# %%
plt.boxplot(data.sqft_living)
plt.xlabel('sqft_living')
plt.show()
plt.savefig(r'C:\Users\Phaneendra\Desktop\box.jpeg')

# %%
plt.boxplot(data.sqft_lot)
plt.xlabel('sqft_lot')
plt.show()

# %% [markdown]
# #### From above graphs we can infer that the distribuition is right skewed and there are outliers

# %% [markdown]
# # bedrooms

# %%
data['bedrooms'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# #### From above graph we can infer that more number of houses have three bedrooms followed by four number of bedrooms

# %% [markdown]
# # Bathrooms

# %%
data['bathrooms'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ### From above graph we can infer that more number of houses have 2.5 bathrooms followed by  one bathroom

# %% [markdown]
# # Waterfront

# %%
data['waterfront'].value_counts().plot(kind='bar')

# %% [markdown]
# #### From above graph we can infer that more than 95% of houses doesn’t have waterfront

# %%
plt.scatter(x=data.grade,y=data.price,color='red')
plt.xlabel('grade')
plt.ylabel('price')
plt.show()

# %% [markdown]
# # grade vs price

# %%
p=pd.DataFrame({'maximum of price':data.groupby(data['grade'])['price'].max()}).reset_index() #grouping grad and mean of prices

# %%
a=p['grade']                                           #plotting betwwen grade and mean of prices
b=p['maximum of price']
f, ax = plt.subplots(figsize=(8,8))
ax=sns.barplot(a,b)

# %% [markdown]
# ###### from above graph we can infer that house with grade 13  has the maximum   price and house with grade 1 lowest
# ###### as the grade increases the prices increase

# %% [markdown]
# # Zipcode vs price

# %%
d=pd.DataFrame({'max of prices':data.groupby(data['zipcode'])['price'].max().sort_values(ascending=False)}).reset_index() #gropinf zipcode and mean of prices

# %%
a=d['zipcode'].head(10)                           #plotiing between zipcode and mean of prices
b=d['max of prices'].head(10)           
f, ax = plt.subplots(figsize=(6,6))
ax=sns.barplot(a,b)

# %% [markdown]
# ### from above graph we can infer that at zipcode 98039 the price of house is high

# %% [markdown]
# # grade vs no of houses

# %%
count=pd.DataFrame({'no of houses':data.groupby(data['grade'])['id'].count()}).reset_index() # grouping data grade and count of house

# %%
count
# Out:
#     grade  no of houses
# 0       1             1
# 1       4            17
# 2       5           107
# 3       6           914
# 4       7          4067
# 5       8          2707
# 6       9          1192
# 7      10           532
# 8      11           172
# 9      12            45
# 10     13             7

# %%
a=count['grade']                    #plotting between grade and no of houses
b=count['no of houses']
f,ax=plt.subplots(figsize=(6,6))
ax=sns.barplot(a,b)

# %% [markdown]
# ###### from the above graph we can infer that with grade 7 there are more no of houses
# ###### with grade 13,12,4,3 there are less number of houses

# %% [markdown]
# # sqft_above vs price

# %%
plt.scatter(x=data['sqft_above'],y=data['price'],color='red')  #plotting between sqft_above and price
plt.xlabel('sqft_above')
plt.ylabel('price')
plt.show()

# %% [markdown]
# ### from above graph we can infer that sqft_above and price are somewhat linearly related

# %% [markdown]
# # year built and max of house price

# %%
count=pd.DataFrame({'max of price':data.groupby(data['yr_built'])['price'].max().sort_values(ascending=False)}).reset_index() #groping max price

# %%
count
# Out:
#      yr_built  max of price
# 0        1910     7700000.0
# 1        2001     6885000.0
# 2        2009     5350000.0
# 3        2004     4500000.0
# 4        2003     4208000.0
# ..        ...           ...
# 111      1903     1020000.0
# 112      1920     1014250.0
# 113      1919      990000.0
# 114      1944      835000.0
# 115      1934      420000.0
#
# [116 rows x 2 columns]

# %%
a=count['yr_built'].head(10)                     #plotting between max price and yr_built
b=count['max of price'].head(10)
fig,ax=plt.subplots(figsize=(6,6))
ax=sns.barplot(a,b)

# %% [markdown]
# ###### from above graph we can infer that the house with max price is built in 1910
# ###### second max price house is built in 1940 and third in 2001

# %% [markdown]
# # max house price deatails

# %%
data[data.price==data.price.max()]  #details of house with max price
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 3303  6762700020  20141013T000000  7700000.0         6        8.0
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 3303        12050     27600     2.5           0     3  ...     13        8570
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 3303           3480      1910          1987    98102  47.6298 -122.323
#
#       sqft_living15  sqft_lot15
# 3303           3940        8800
#
# [1 rows x 21 columns]

# %% [markdown]
# # min house price details

# %%
data[data.price==data.price.min()]  #details of house with minimum price
# Out:
#              id             date    price  bedrooms  bathrooms  sqft_living  \
# 213  8658300340  20140523T000000  80000.0         1       0.75          430
#
#      sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 213      5050     1.0           0     0  ...      4         430
#
#      sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 213              0      1912             0    98014  47.6499 -121.909
#
#      sqft_living15  sqft_lot15
# 213           1200        7500
#
# [1 rows x 21 columns]

# %% [markdown]
# # features of medium house

# %%
data[data.price==data.price.median()] #details of house with medium price
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 182   7821200390  20140806T000000  450000.0         3       2.00         1290
# 395   2296500036  20150310T000000  450000.0         4       2.75         2980
# 613    217500135  20150421T000000  450000.0         4       2.25         2040
# 614   3731800055  20140605T000000  450000.0         4       1.00         2000
# 626   9468200140  20140819T000000  450000.0         2       1.75         1250
# ...          ...              ...       ...       ...        ...          ...
# 8892  3204300610  20141202T000000  450000.0         2       1.00          950
# 8905   224059021  20141219T000000  450000.0         3       1.00         1150
# 8965  4019500030  20141029T000000  450000.0         3       2.50         2280
# 8983  2867300160  20140904T000000  450000.0         5       3.50         3931
# 9026  7853321090  20141001T000000  450000.0         3       2.50         2410
#
# ...

# %% [markdown]
# # view vs price

# %%
view=pd.DataFrame({'max of prices':data.groupby(data['view'])['price'].mean()}).reset_index() #groping by mean of prices

# %%
a=view['view']                               #plotting between mean of prices and view
b=view['max of prices']
fig,ax=plt.subplots(figsize=(6,6))
ax=sns.barplot(a,b)

# %% [markdown]
# ###### from above graph we can infer that house with view=4 has the maximum price
# ###### and low with view=0

# %% [markdown]
# ## bedrooms,bathrooms,floors vs price

# %%
bed=pd.DataFrame({'max of prices':data.groupby(data['floors'])['price'].max()}).reset_index()

# %%
a=bed['floors']
b=bed['max of prices']
sns.barplot(a,b);

# %%
a=data['bathrooms']
b=data['price']
fig,ax=plt.subplots(figsize=(10,10))
sns.barplot(a,b);

# %%
a=data['floors']
b=data['price']
sns.barplot(a,b);

# %%
a=data['waterfront']
b=data['price']
sns.barplot(a,b);

# %% [markdown]
# # Anamoly detection

# %%
data.boxplot(column='price',by='bedrooms',grid=False,figsize=(12,12))

# %%
data[data.bedrooms ==33 ]
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 7204  2402100895  20140625T000000  640000.0        33       1.75         1620
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7204      6000     1.0           0     0  ...      7        1040
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7204            580      1947             0    98103  47.6878 -122.331
#
#       sqft_living15  sqft_lot15
# 7204           1330        4700
#
# [1 rows x 21 columns]

# %%
data[data.bedrooms ==10 ]
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 6876  5566100170  20141029T000000  650000.0        10        2.0         3610
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 6876     11914     2.0           0     0  ...      7        3010
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 6876            600      1958             0    98006  47.5705 -122.175
#
#       sqft_living15  sqft_lot15
# 6876           2040       11914
#
# [1 rows x 21 columns]

# %%
data[data.bedrooms ==11 ]
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 4011  1773100755  20140821T000000  520000.0        11        3.0         3000
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 4011      4960     2.0           0     0  ...      7        2400
#
#       sqft_basement  yr_built  yr_renovated  zipcode     lat     long  \
# 4011            600      1918          1999    98106  47.556 -122.363
#
#       sqft_living15  sqft_lot15
# 4011           1420        4960
#
# [1 rows x 21 columns]

# %% [markdown]
# ### from the above information we can say that 33 bedrooms is an anamoly so either we will remove it or replace with other suitable value
